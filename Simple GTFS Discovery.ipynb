# %%
import pandas as pd

# %%
agency = pd.read_csv("./data/agency.txt")
agency
# Out:
#      agency_id             agency_name  \
# 0        ALLGO          allGo (Keolis)
# 1          ARR                  Arriva
# 2    BRAVO:ARR          Bravo (Arriva)
# 3    BRAVO:CXX          Bravo (Hermes)
# 4        BRENG                   Breng
# 5          CXX              Connexxion
# 6          EBS                     EBS
# 7           FF     Westerschelde Ferry
# 8          GVB                     GVB
# 9          HTM                     HTM
# 10     HTMBUZZ                 HTMbuzz
# 11    IFF:ABRN        Abellio Rail NRW
# 12      IFF:BN                Blauwnet
# 13   IFF:BRENG                   Breng
# 14     IFF:GVB                     GVB
# 15   IFF:NOORD                  Arriva
# 16      IFF:NS                      NS
# 17     IFF:NSI        NS International
# 18     IFF:RET                     Ret
# 19    IFF:RNET                   R-net
# 20  IFF:VALLEI              Valleilijn
# 21    LEVELINK                LEVELINK
# 22        NIAG                    NIAG
# ...

# %%
stops = pd.read_csv("./data/stops.txt")

# %%
stops.head()
# Out:
#   stop_id  stop_code                   stop_name   stop_lat  stop_lon  \
# 0       1        NaN  Arnhem, Station Presikhaaf  51.987910  5.941563
# 1      10        NaN    Doesburg, Tunnel Angerlo  51.997992  6.129636
# 2     100        NaN       Groenlo, De Molenberg  52.041598  6.613116
# 3    1004        NaN            Warnsveld, GGNet  52.131585  6.249971
# 4    1005        NaN          Neede, Chr. School  52.134124  6.597149
#
#    location_type parent_station stop_timezone  wheelchair_boarding  \
# 0              0            NaN           NaN                  1.0
# 1              0            NaN           NaN                  1.0
# 2              0            NaN           NaN                  0.0
# 3              0            NaN           NaN                  1.0
# 4              0            NaN           NaN                  1.0
#
#   platform_code
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
l = stops[stops['stop_name'].str.contains("Mekelpark")]
l
# Out:
#       stop_id  stop_code              stop_name   stop_lat  stop_lon  \
# 517   1099928        NaN    Delft, TU Mekelpark  51.999201  4.373961
# 520   1099931        NaN    Delft, TU Mekelpark  51.999676  4.373805
# 2674  1216986        NaN  Delft, TU - Mekelpark  51.999667  4.373820
# 3109  1217481        NaN  Delft, TU - Mekelpark  51.999256  4.374106
#
#       location_type parent_station stop_timezone  wheelchair_boarding  \
# 517               0            NaN           NaN                  1.0
# 520               0            NaN           NaN                  1.0
# 2674              0            NaN           NaN                  1.0
# 3109              0            NaN           NaN                  1.0
#
#      platform_code
# 517            NaN
# 520            NaN
# 2674           NaN
# 3109           NaN

# %%
import mplleaflet
import matplotlib.pyplot as plt
plt.scatter(l['stop_lon'], l['stop_lat'])
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %%
stop_times = pd.read_csv('./data/stop_times.txt')

# %%
stop_times.head()
# Out:
#     trip_id  stop_sequence  stop_id stop_headsign arrival_time departure_time  \
# 0  65406836             10   237983           NaN     18:28:22       18:28:40
# 1  65408480             10   237983           NaN     19:28:22       19:28:40
# 2  65400211             10   237983           NaN     10:35:22       10:35:40
# 3  65420679             10   237983           NaN     24:50:22       24:50:40
# 4  65395053             10   237983           NaN     20:22:22       20:22:40
#
#    pickup_type  drop_off_type  timepoint  shape_dist_traveled  \
# 0            0              0          0               8122.0
# 1            0              0          0               8122.0
# 2            0              0          0               8122.0
# 3            0              0          0               8122.0
# 4            0              0          0               8122.0
#
#    fare_units_traveled
# 0                 8122
# 1                 8122
# 2                 8122
# 3                 8122
# ...

# %%
mekelpark = stop_times.merge(l)
mekelpark.head()
# Out:
# Empty DataFrame
# Columns: [trip_id, stop_sequence, stop_id, stop_headsign, arrival_time, departure_time, pickup_type, drop_off_type, timepoint, shape_dist_traveled, fare_units_traveled, stop_code, stop_name, stop_lat, stop_lon, location_type, parent_station, stop_timezone, wheelchair_boarding, platform_code]
# Index: []

# %%
stops = stop_times[stop_times['stop_id'] == 1099928]

# %%
copy = stops.copy()

# %%
copy

copy.sort_values('arrival_time')
# Out:
#           trip_id  stop_sequence  stop_id stop_headsign arrival_time  \
# 1556162  73741441              6  1099928           NaN     06:23:32
# 1554425  73927511              6  1099928           NaN     06:23:32
# 429301   73739608              6  1099928           NaN     07:16:43
# 875216   73920464              6  1099928           NaN     07:16:43
# 1473245  73931670              6  1099928           NaN     07:22:43
# 1472515  73745149              6  1099928           NaN     07:22:43
# 426018   73728843              6  1099928           NaN     07:46:43
# 875433   73912831              6  1099928           NaN     07:46:43
# 1576640  73922617              6  1099928           NaN     07:51:43
# 1575503  73737353              6  1099928           NaN     07:51:43
# 1578097  73741443              6  1099928           NaN     08:12:43
# 1576203  73927513              6  1099928           NaN     08:12:43
# 422723   73735390              6  1099928           NaN     08:17:43
# ...
